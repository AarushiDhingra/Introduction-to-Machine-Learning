# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### NYC_W.CSV
# ### 1. Find Date with Min Temp and Max Temp.
# ### 2. Find miN Temp with Event (Col) - Sunny, Date for Same
# ### 3. Find All Dates where Events is NaN

# %%
df = pd.read_csv('nyc_weather.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# ...

# %%
df.shape
# Out:
# (31, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# ...

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df.keys
# Out:
# <bound method NDFrame.keys of           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    01/01/16           38        23        52                 30.03
# 1    01/02/16           36        18        46                 30.02
# 2    01/03/16           40        21        47                 29.86
# 3    01/04/16           25         9        44                 30.05
# 4    01/05/16           20        -3        41                 30.57
# 5    01/06/16           33         4        35                 30.50
# 6    01/07/16           39        11        33                 30.28
# 7    01/08/16           39        29        64                 30.20
# 8    01/09/16           44        38        77                 30.16
# 9    01/10/16           50        46        71                 29.59
# 10   01/11/16           33         8        37                 29.92
# 11   01/12/16           35        15        53                 29.85
# ...

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01/01/16           38        23        52                 30.03
# 1  01/02/16           36        18        46                 30.02
# 2  01/03/16           40        21        47                 29.86
# 3  01/04/16           25         9        44                 30.05
# 4  01/05/16           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df["Temperature"]
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df[22:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# ...

# %%
df[df.Temperature == min(df.Temperature)].EST
# Out:
# 4    01/05/16
# Name: EST, dtype: object

# %%
df[df.Temperature == max(df.Temperature)].EST
# Out:
# 9    01/10/16
# Name: EST, dtype: object

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df.Events.unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df[(df.Events != "Rain") & (df.Events != "Fog-Snow") & (df.Events != "Snow")].EST
# Out:
# 0      01/01/16
# 1      01/02/16
# 2      01/03/16
# 3      01/04/16
# 4      01/05/16
# 5      01/06/16
# 6      01/07/16
# 7      01/08/16
# 10     01/11/16
# 11     01/12/16
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 24    1/25/2016
# 25    1/26/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df[(df.Events.isnull())].EST
# Out:
# 0      01/01/16
# 1      01/02/16
# 2      01/03/16
# 3      01/04/16
# 4      01/05/16
# 5      01/06/16
# 6      01/07/16
# 7      01/08/16
# 10     01/11/16
# 11     01/12/16
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 24    1/25/2016
# 25    1/26/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object
